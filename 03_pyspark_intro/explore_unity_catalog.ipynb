-- %%
SHOW CATALOGS;

-- %%
SHOW SCHEMAS IN data2;

-- %%
SHOW VOLUMES IN data2.olympic_games;

LIST '/Volumes/data2/olympic_games/raw_data';

-- %%
%python
_sqldf.display()

-- %%
%python
volume_path = '/Volumes/data2/olympic_games/raw_data'

files_in_volume = spark.sql(f"LIST '{volume_path}';")
files_in_volume # lazy evaluation, we see the schema, not the actual data

-- %%
%python
display(files_in_volume)
