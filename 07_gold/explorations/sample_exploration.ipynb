# %% [markdown]
# ### Example Exploratory Notebook
#
# Use this notebook to explore the data generated by the pipeline in your preferred programming language.
#
# **Note**: This notebook is not executed as part of the pipeline.

# %%
import sys

sys.path.append("/Workspace/Users/kokchungiang@gmail.com/databricks_azure_code_alongs_de25/05_bronze")

# %%
# !!! Before performing any data analysis, make sure to run the pipeline to materialize the sample datasets. The tables referenced in this notebook depend on that step.

display(spark.sql("SELECT * FROM workspace.default.sample_aggregation_supply_chain_demo"))
